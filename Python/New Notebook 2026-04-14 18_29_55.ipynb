# %%
name ="Sritham"
print(name)

# %%
a = '10'
type(a)

# %%
salary = 250000
print(salary)

# %%
name ='sritham'
print(f'My name is {name}')

# %%
# LIST AND DICTIONARY are mutable 
employee =['srtfd','3',True]
print(employee[2])
employee[0:1:2]
employee[-2] = 122
print(employee)

# %%
#  DICTIONARY

employee = {'name':'sritham','salary':250000,'married':True}
print(employee['salary'])

# %%
def greet(name):
  print(f'Hello {name}')
greet('sritham')

# %%
def calculate_bonus(salary):
    if salary > 50000:
         return "Bonus"
    return "No Bonus"

# %%
calculate_bonus(100000)

# %%
Salary = int(input("Enter Salary"))
if salary >= 34444:
  print("Bonus")
elif salary >= 344:
  print("No Bonus")
else :
    print("No Bonus")

# %%
import csv

with open('/Volumes/man_cata/default/global/global_food_wastage_dataset.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)

# %%
display(dbutils.fs.ls('/Volumes/man_cata/default/global'))

# %%
with open('output.csv',mode='w',newline='') as file:
    writer= csv.writer(file)
    writerrows = ['name','salary','married']
    writer.writerow(writerrows)

# %%
# try-except

try:
    marks = int(input("Enter your marks: "))
    print("Normalized Score:", 100 / marks)

except ZeroDivisionError:
    print("❌ Cannot divide by zero")

except ValueError:
    print("❌ Please enter a valid number")

# %%
import logging

logging.basicConfig(level=logging.DEBUG)

logging.debug("🛠 Debug — Internal variable set")
logging.info("ℹ️ Info — Starting process")
logging.warning("⚠️ Warning — Using default config")
logging.error("❌ Error — Invalid input received")
logging.critical("🔥 Critical — System failure")

# %%
name  = 'sritham'
print(len(name))

# %%
arr = [1,5,9,7]
print(sorted(arr))

# %%
arr= [-15,6,8,7]
print(max(arr, key = lambda x:abs(x)))

# %%
print(sum(arr,start =10))

# %%
import math
arr= [-15,6,8,7]
print(math.prod(arr))

# %%
def count_in_list(arr,number):
    cnt=0
    for el in arr:
        if el==number:
            cnt+=1
    return cnt


arr =[1,2,4,5,1]
print(count_in_list(arr,1))

# %%
arr =[1,2,4,5,1]
print(arr.count(1))

# %%
arr =[1,2,4,5,1]
print(list(reversed(arr)))

# %%
from collections import deque
dq = deque([2,3,1])
dq.append(5)
print(dq)

dq.appendleft(1)
print(dq)

dq.pop()
print(dq)

dq.popleft()
print(dq)

dq.extend([1,2,3])
print(dq)

dq.extendleft([1,2,3])
print(dq)

dq.rotate(2)
print(dq)

# %%
from collections import Counter
arr = Counter([1,2,3,4,5,6,7,5,4,8,9,10])
print((arr[5]))
print(arr.most_common(2))
print(arr.most_common())

# %%
dd = defaultdict(int)
dd[1] = "sritham"
dd["subha"] = "da"
dd['w'] =98

# %%
from collections import OrderedDict

od = OrderedDict([(5,"sritham"),(2,"subha"),(4,"da"),(1,"w")])
print(od)

# %%
val = (1,3,4)
print(val)

# %% [markdown]
# custom class declaration

# %%
class pair:
  def __init__(self, x, y):
    self.x = x
    self.y = y
    val  = pair(2,9)
    print(val.x)

# %% [markdown]
# Heap-priority

# %%
import heapq

val = []
heapq.heappush(val, 10)
heapq.heappush(val, 1)
heapq.heappush(val, 3)
heapq.heappush(val, 2)
heapq.heappush(val, 5)

print(val)

# %%
heapq.heappop(val)
print(val)

# %% [markdown]
# head pushpop
# firstb the pushhappens the its pops out the smallest number

# %% [markdown]
# headpreplace first it delete the value and then push

# %%
print(heapq.nsmallest(4,[4,2,5,6,10]))

# %% [markdown]
# heapify

# %%
arr=[4,43,3,23,535]
heapq.heapify(arr)
print(arr)

# %% [markdown]
# Bisect binary search(assumer array is sorted)
# --linear seach over all list

# %%
def linear_search(arr, val):
    for i in range(0, len(arr)):
        if arr[i] == val:
            return i
    return -1

arr = [5, 1, 6, 1, 7, 10]
print(linear_search(arr, 16))

# %%
import bisect

arr = [4, 5, 5, 6, 7, 7, 8, 10, 12, 12, 13]

print(bisect.bisect_left(arr, 11))
bisect.insort(arr,5)
print(arr)

# %%
import itertools

arr = [1, 5, 6, 7]

print(list(itertools.combinations(arr, 2)))

# %%
import itertools

arr1 = [1, 2]
arr2 = [3, 4]
arr3 = [5, 6]

print(list(itertools.product(arr1, arr2, arr3)))

# %%
arr = list(itertools.repeat(5, 6))
print(arr)

# %%
import itertools

print(list(itertools.chain([1, 2], [5, 6], [3, 4])))

# %%
import math
math.sqrt(16)                  # Square root: 4.0
math.pow(2, 3)                 # 2^3: 8.0
math.factorial(5)              # 5!: 120
math.gcd(48, 18)               # GCD: 6
math.lcm(12, 8)                # LCM: 24 (Python 3.9+)
math.log(math.e)               # Natural log: 1.0
math.log10(100)                # Base 10 log: 2.0
math.log2(8)                   # Base 2 log: 3.0
math.sin(math.pi/2)            # sin(90°): 1.0
math.cos(0)                    # cos(0°): 1.0
math.degrees(math.pi)          # Radians to degrees: 180.0
math.radians(180)              # Degrees to radians: 3.14159...
math.ceil(4.3)                # Ceiling: 5
math.floor(4.7)                # Floor: 4
math.isfinite(10)              # Check if finite: True
math.isinf(float('inf'))       # Check if infinite: True

# %%
import random
random.random()                # Float in [0.0, 1.0): 0.123456...
random.randint(1, 10)           # Integer in [1, 10]: 7 (example)
random.randrange(0, 10, 2)     # Even numbers 0-8: 4 (example)
random.choice([1, 2, 3, 4])    # Random element: 3 (example)
random.sample([1,2,3,4,5], 3)  # 3 random elements: [2, 5, 1] (example)
arr = [1, 2, 3, 4, 5]
random.shuffle(arr)            # Shuffle in-place: arr = [3, 1, 5, 2, 4] (example)
random.uniform(1.0, 10.0)      # Float in [1.0, 10.0]: 5.678... (example)

# %%
lst = [1, 2, 3]
lst.append(4)                  # Add to end: [1, 2, 3, 4]
lst.extend([5, 6])             # Extend: [1, 2, 3, 4, 5, 6]
lst.insert(0, 0)              # Insert at index 0: [0, 1, 2, 3, 4, 5, 6]
lst.remove(3)                  # Remove first 3: [0, 1, 2, 4, 5, 6]
lst.pop()                      # Remove last: returns 6, lst = [0, 1, 2, 4, 5]
lst.pop(0)                     # Remove at index 0: returns 0, lst = [1, 2, 4, 5]
lst.index(2)                   # Index of 2: 1
lst.count(2)                   # Count of 2: 1
lst.sort()                     # Sort: [1, 2, 4, 5]
lst.sort(reverse=True)         # Sort descending: [5, 4, 2, 1]
lst.reverse()                  # Reverse: [1, 2, 4, 5]
lst.clear()                    # Clear: []
lst = [1, 2, 3]
lst2 = lst.copy()              # Shallow copy: [1, 2, 3]

# %%
d = {'a': 1, 'b': 2}
d['a']                         # Get value: 1
d['c']                         # KeyError (missing key)
d.get('a')                     # Get value: 1
d.get('c', 0)                  # Get with default: 0
d['c'] = 3                     # Set value: {'a': 1, 'b': 2, 'c': 3}
d.update({'d': 4})             # Update: {'a': 1, 'b': 2, 'c': 3, 'd': 4}
d.pop('c')                     # Remove and return: 3
d.pop('x', -1)                 # Remove with default: -1 (key not found)
d.popitem()                    # Remove last: ('d', 4)
list(d.keys())                 # View of keys: ['a', 'b']
list(d.values())               # View of values: [1, 2]
list(d.items())                # View of pairs: [('a', 1), ('b', 2)]
d.clear()                      # Clear: {}
d = {'a': 1, 'b': 2}
'a' in d                       # Check if key exists: True
d2 = d.copy()                  # Shallow copy: {'a': 1, 'b': 2}

# %% [markdown]
# set wont allow to store duplicates

# %%
st ={1,4,5,2}
print(st)
